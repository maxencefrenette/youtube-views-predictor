# %% [markdown]
# # Models
#
#
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read CSV file containing YouTube video data

# %%
# TODO: Make this part of another notebook or .py file that is used to process and split the data

# Read CSV file
yt_data = pd.read_csv('../data/youtube_video_data.csv')

# Drop the CSV file's numeric row count/index column
yt_data = yt_data.drop('Unnamed: 0', axis=1)

# Convert 2 date columns into datetime objects
yt_data['video_published_at'] = pd.to_datetime(yt_data['video_published_at'])
yt_data['channel_published_at'] = pd.to_datetime(yt_data['channel_published_at'])

# Output the dataframe
yt_data
# Out:
#          video_id                                              title  \
# 0     x_t53a5Ons0  Metallica: If Darkness Had a Son (Official Mus...
# 1     WM8bTdBs-cw              Metallica: One (Official Music Video)
# 2     qz8yjPTMJf4  Metallica: Screaming Suicide (Official Lyric V...
# 3     _u-7rWKnVVo       Metallica: Lux Æterna (Official Music Video)
# 4     CD-E-LDc384    Metallica: Enter Sandman (Official Music Video)
# ...           ...                                                ...
# 1269  UKqkb4cEy-E  Miquella and Malenia: The Full Story | Elden R...
# 1270  _Pd5weoBjcE  Can I Beat Elden Ring While Getting Hit By Eve...
# 1271  hX7xcxpxHhU    Can I Beat Elden Ring by 1 Shotting the Bosses?
# 1272  m4YZcEc1qgI               Elden Ring Lore | Morgott: His Story
# 1273  3MtHTKpH9IM         The ULTIMATE Elden Ring Location Tier List
#
#                                             description  \
# 0     Metallica's official music video for “If Darkn...
# 1     Metallica's official music video for “One,” fr...
# 2     Metallica’s official lyric video, “Screaming S...
# 3     Metallica's official music video for “Lux Æter...
# 4     Metallica's official music video for “Enter Sa...
# ...                                                 ...
# 1269  Of all the twins in Elden Ring (which there is...
# 1270  Thanks to Keeps for sponsoring - Head to https...
# 1271  Enjoy!\n\n------------------------------------...
# 1272  The Lore of Morgott in Elden Ring is a tale fo...
# 1273  In this Elden Ring video, all of the locations...
#
#             video_published_at  hours_published_video  num_tags    channel  \
# 0    2023-03-01 15:00:43+00:00              14.864821         8  Metallica
# 1    2009-10-27 01:53:30+00:00          116979.985099         7  Metallica
# 2    2023-01-25 14:01:00+00:00             855.860099         8  Metallica
# 3    2022-11-28 15:00:20+00:00            2246.871210         8  Metallica
# 4    2012-03-19 20:34:06+00:00           95985.308432         7  Metallica
# ...                        ...                    ...       ...        ...
# 1269 2022-12-21 15:05:01+00:00            1694.793154         5    V-Limit
# 1270 2022-11-05 09:57:21+00:00            2803.920932         0      Bushy
# 1271 2022-05-16 14:00:18+00:00            6951.871765         1      Bushy
# 1272 2023-02-10 21:03:57+00:00             464.810932        19   Hawkshaw
# 1273 2022-07-15 13:24:32+00:00            5512.467876         0  Dark Tark
#
#                     channel_id  \
# 0     UCbulh9WdLtEXiooRcYK7SWw
# 1     UCbulh9WdLtEXiooRcYK7SWw
# 2     UCbulh9WdLtEXiooRcYK7SWw
# 3     UCbulh9WdLtEXiooRcYK7SWw
# 4     UCbulh9WdLtEXiooRcYK7SWw
# ...                        ...
# 1269  UCAXzwpv-8zX3uI95W7YfGYA
# 1270  UCF5RrlbsxJjAVLWgOCoNHMg
# 1271  UCF5RrlbsxJjAVLWgOCoNHMg
# 1272  UC47GDLUPXADaa69O2AqJQ9A
# 1273  UCRqTUdxEg-5cYK7MbCxU4Dw
#
#                                        thumbnail_url  thumbnail_width  ...  \
# 0     https://i.ytimg.com/vi/x_t53a5Ons0/default.jpg              120  ...
# 1     https://i.ytimg.com/vi/WM8bTdBs-cw/default.jpg              120  ...
# 2     https://i.ytimg.com/vi/qz8yjPTMJf4/default.jpg              120  ...
# 3     https://i.ytimg.com/vi/_u-7rWKnVVo/default.jpg              120  ...
# 4     https://i.ytimg.com/vi/CD-E-LDc384/default.jpg              120  ...
# ...                                              ...              ...  ...
# 1269  https://i.ytimg.com/vi/UKqkb4cEy-E/default.jpg              120  ...
# 1270  https://i.ytimg.com/vi/_Pd5weoBjcE/default.jpg              120  ...
# 1271  https://i.ytimg.com/vi/hX7xcxpxHhU/default.jpg              120  ...
# 1272  https://i.ytimg.com/vi/m4YZcEc1qgI/default.jpg              120  ...
# 1273  https://i.ytimg.com/vi/3MtHTKpH9IM/default.jpg              120  ...
#
#           views      likes favorites  comments  \
# 0       1190584   104266.0         0   11027.0
# 1     279959343  1691453.0         0   76073.0
# 2        278112    12501.0         0     876.0
# 3      15976078   483175.0         0   46518.0
# 4     578225232  2857927.0         0   81851.0
# ...         ...        ...       ...       ...
# 1269     207776     8620.0         0     462.0
# 1270    1963328    46974.0         0    2370.0
# 1271    5840506   124835.0         0    3366.0
# 1272      61256     3828.0         0     338.0
# 1273     403969    16203.0         0     646.0
#
#                                     channel_description  \
# 0                The Official Metallica YouTube Channel
# 1                The Official Metallica YouTube Channel
# 2                The Official Metallica YouTube Channel
# 3                The Official Metallica YouTube Channel
# 4                The Official Metallica YouTube Channel
# ...                                                 ...
# 1269  Explaining lore and solving mysteries in gamin...
# 1270                                                NaN
# 1271                                                NaN
# 1272  Welcome to Hawkshaw, a channel for going in de...
# 1273  Meme channel.\n\nMain Channel: https://www.you...
#
#           channel_published_at  days_published_channel  channel_views  \
# 0    2007-01-30 00:12:55+00:00             5875.236114     5029599596
# 1    2007-01-30 00:12:55+00:00             5875.236114     5029599596
# 2    2007-01-30 00:12:55+00:00             5875.236114     5029599596
# 3    2007-01-30 00:12:55+00:00             5875.236114     5029599596
# 4    2007-01-30 00:12:55+00:00             5875.236114     5029599596
# ...                        ...                     ...            ...
# 1269 2022-03-16 02:18:28+00:00              351.148926        4894758
# 1270 2022-01-13 23:41:15+00:00              412.258104       33914550
# 1271 2022-01-13 23:41:15+00:00              412.258104       33914550
# 1272 2015-10-28 14:32:24+00:00             2681.639250        8515004
# 1273 2021-02-09 06:38:21+00:00              750.968452        9717653
#
#      channel_videos channel_subscribers
# 0              1819             9460000
# 1              1819             9460000
# 2              1819             9460000
# 3              1819             9460000
# 4              1819             9460000
# ...             ...                 ...
# 1269             19               33900
# 1270             39              241000
# 1271             39              241000
# 1272             28               78700
# 1273             50              116000
#
# [1274 rows x 24 columns]

# %% [markdown]
# ### Describe the dataframe

# %%
print("Shape: ", yt_data.shape, "\n")
yt_data.describe()
# Out:
# Shape:  (1274, 24)
#        hours_published_video     num_tags  thumbnail_width  thumbnail_height  \
# count            1274.000000  1274.000000           1274.0            1274.0
# mean             6068.009250    16.653846            120.0              90.0
# std             12981.101093    13.543980              0.0               0.0
# min                 0.875099     0.000000            120.0              90.0
# 25%                73.789265     3.000000            120.0              90.0
# 50%              1010.603293    16.000000            120.0              90.0
# 75%              5506.223710    27.000000            120.0              90.0
# max            116979.985099    74.000000            120.0              90.0
#
#            duration         views         likes  favorites       comments  \
# count   1274.000000  1.274000e+03  1.271000e+03     1274.0    1266.000000
# mean    1189.474097  6.031095e+06  8.459805e+04        0.0    4270.718009
# std     1902.158400  3.411884e+07  2.502717e+05        0.0   10001.176001
# min        0.000000  7.000000e+00  0.000000e+00        0.0       0.000000
# 25%      399.000000  1.355218e+05  5.029000e+03        0.0     363.000000
# 50%      759.500000  7.039905e+05  2.141400e+04        0.0    1302.000000
# 75%     1391.000000  2.750673e+06  7.147100e+04        0.0    3996.250000
# max    43724.000000  5.816827e+08  3.725167e+06        0.0  146048.000000
#
#        days_published_channel  channel_views  channel_videos  \
# count             1274.000000   1.274000e+03     1274.000000
# mean              3132.719073   1.919969e+09     2261.682104
# std               1806.968106   4.039485e+09     7003.176064
# min                  9.119690   5.320000e+02        1.000000
# 25%               1644.449030   5.373842e+07      139.000000
# 50%               2978.274852   4.654926e+08      335.500000
# 75%               4216.257500   1.534410e+09     1134.750000
# max               6375.429748   2.930093e+10   112462.000000
#
#        channel_subscribers
# count         1.274000e+03
# mean          5.015398e+06
# std           9.831193e+06
# min           1.000000e+01
# 25%           3.055000e+05
# 50%           1.590000e+06
# 75%           5.960000e+06
# max           1.360000e+08

# %% [markdown]
# ### Randomize the indices

# %%
np.random.seed(0)
yt_data = yt_data.reindex(np.random.permutation(yt_data.shape[0]))

yt_data
# Out:
#          video_id                                              title  \
# 1179  NFjn0X2BL2Q         La Comadre | EVERYNIGHTNIGHTS PODCAST #184
# 1120  EN4izhntW1g               Cooking Expensive Steak in a Toaster
# 427   hX_qyf38X9c  Can I Survive 100 Days in Hardcore Survival Mo...
# 351   Qek_UPifJhs      Don Toliver - Time Heals All [Official Audio]
# 364   iEPxe5c282E  Real Madrid CF v Al Ain | FIFA Club World Cup ...
# ...           ...                                                ...
# 763   3PnOS94d6v0     I Surprised My Girlfriend With A Custom House!
# 835   ymGt7I4Yn3k  Russell's Paradox - a simple explanation of a ...
# 1216  pl80_nOEgbw    Will Anyone Ever Break LeBron's Scoring Record?
# 559   qAtyzHZc7l8                    Unluckiest People In The World!
# 684   tBd-T6o1_4s   Super Mario Growing Up Compilation | Cartoon Wow
#
#                                             description  \
# 1179  👩‍👩‍👧‍👦BECOME A MEMBER FOR EXCLUSIVE CONTENT, ...
# 1120  follow me on twitter ► https://www.twitter.com...
# 427   Welcome back to skyrim! Where today we set out...
# 351   Don Toliver - Time Heals All\n'LOVE SICK' the ...
# 364   FULL MATCH: Rewatch Real Madrid v Al Ain the 2...
# ...                                                 ...
# 763   I cant believe I painted our $10,000,000 house...
# 835   This is a video lecture explaining Russell's P...
# 1216  For 65% off with HelloFresh PLUS free shipping...
# 559   imagine being so unlucky you end up in this vi...
# 684   Super Mario Growing Up Compilation | Cartoon W...
#
#             video_published_at  hours_published_video  num_tags  \
# 1179 2023-02-22 05:28:56+00:00             192.394543        16
# 1120 2023-03-01 06:00:01+00:00              23.876488         8
# 427  2022-11-05 19:21:23+00:00            2794.520376        32
# 351  2023-02-24 05:00:11+00:00             144.873710        28
# 364  2023-02-10 18:52:49+00:00             466.996488        28
# ...                        ...                    ...       ...
# 763  2021-09-22 21:20:48+00:00           12608.530099         0
# 835  2022-09-08 15:18:27+00:00            4190.569265         0
# 1216 2023-02-26 23:48:26+00:00              78.069543        29
# 559  2023-02-24 21:00:10+00:00             128.873988        25
# 684  2022-12-10 12:48:10+00:00            1961.073988        24
#
#                 channel                channel_id  \
# 1179       everydaydays  UC62DsCYR_xWzxeH8ou1WKlg
# 1120             Ludwig  UCrPseYLGpNygVi34QpGNqpA
# 427   The Spiffing Brit  UCRHXUZ0BxbkU2MYZgsuFgkQ
# 351         Don Toliver  UCgT01FILdWB9BsXBXKjpQ7A
# 364                FIFA  UCpcTrCXblq78GZrTUTLWeBw
# ...                 ...                       ...
# 763                 ZHC  UClQubH2NeMmGLTLgNdLBwXg
# 835      Jeffrey Kaplan  UC_hukbByJP7OZ3Xm2tszacQ
# 1216     JxmyHighroller  UC3L9XPe0_FGfRG-CMGtBvFg
# 559        Beast Reacts  UCUaT_39o1x6qWjz7K2pWcgw
# 684         Cartoon WOW  UCZdaZSFMmxE99qgilfpF1iw
#
#                                        thumbnail_url  thumbnail_width  ...  \
# 1179  https://i.ytimg.com/vi/NFjn0X2BL2Q/default.jpg              120  ...
# 1120  https://i.ytimg.com/vi/EN4izhntW1g/default.jpg              120  ...
# 427   https://i.ytimg.com/vi/hX_qyf38X9c/default.jpg              120  ...
# 351   https://i.ytimg.com/vi/Qek_UPifJhs/default.jpg              120  ...
# 364   https://i.ytimg.com/vi/iEPxe5c282E/default.jpg              120  ...
# ...                                              ...              ...  ...
# 763   https://i.ytimg.com/vi/3PnOS94d6v0/default.jpg              120  ...
# 835   https://i.ytimg.com/vi/ymGt7I4Yn3k/default.jpg              120  ...
# 1216  https://i.ytimg.com/vi/pl80_nOEgbw/default.jpg              120  ...
# 559   https://i.ytimg.com/vi/qAtyzHZc7l8/default.jpg              120  ...
# 684   https://i.ytimg.com/vi/tBd-T6o1_4s/default.jpg              120  ...
#
#          views     likes favorites  comments  \
# 1179    135680    5672.0         0     332.0
# 1120    436352   26944.0         0     755.0
# 427    1448394   69046.0         0    4164.0
# 351     165468    7715.0         0     139.0
# 364     366302    7719.0         0      52.0
# ...        ...       ...       ...       ...
# 763   41197303  893895.0         0   36158.0
# 835    1944400   32361.0         0    7227.0
# 1216   1105686   71047.0         0    5618.0
# 559    5737558  201115.0         0    3746.0
# 684    2474487   10930.0         0     266.0
#
#                                     channel_description  \
# 1179  Snow Tha Products Vlog and Everynightnights Li...
# 1120     if ur reading this please click subscribe :)\n
# 427   Hey all welcome to the channel\n\nContent is m...
# 351   Soul singer, songwriter, artist, and Houston, ...
# 364   FIFA on YouTube brings you the best in footbal...
# ...                                                 ...
# 763   SUBSCRIBE FOR GOOD LUCK!\n\nInstagram: @zhc\nB...
# 835   I am an Assistant Professor of Philosophy at t...
# 1216  Bringing you the best content on all things ba...
# 559   SUBSCRIBE FOR A COOKIE\nMrBeast and Chris reac...
# 684   Welcome to Cartoon Wow!\nOur channel synthesiz...
#
#           channel_published_at  days_published_channel  channel_views  \
# 1179 2017-01-24 04:26:47+00:00             2228.059817       26033014
# 1120 2011-08-15 11:32:54+00:00             4216.763903     1097784011
# 427  2013-10-10 19:06:47+00:00             3429.448706      677173060
# 351  2017-09-28 16:26:38+00:00             1980.559921      798591626
# 364  2006-09-06 03:52:41+00:00             6021.083498     5235752637
# ...                        ...                     ...            ...
# 763  2013-08-07 03:22:54+00:00             3494.104181     2487105744
# 835  2013-02-19 00:22:27+00:00             3663.229493        3784808
# 1216 2007-11-23 10:04:29+00:00             5577.825303      391654752
# 559  2016-04-24 20:43:46+00:00             2502.381357     3378316306
# 684  2021-10-16 04:33:37+00:00              502.055072       78175163
#
#      channel_videos channel_subscribers
# 1179            397              426000
# 1120           1299             4080000
# 427             563             3470000
# 351             154             1590000
# 364           10508            19000000
# ...             ...                 ...
# 763             305            25000000
# 835              92               64800
# 1216            179             2230000
# 559             236            21900000
# 684             227              216000
#
# [1274 rows x 24 columns]

# %% [markdown]
# ### Data preprocessing

# %%
# Filter to show columns with NaN values
na_cols = yt_data.columns[yt_data.isna().any()]
print(yt_data[na_cols].isna().sum())
# Out:
# description             26
# likes                    3
# comments                 8
# channel_description    121
# dtype: int64

# %%
#fill missing likes based on like_to_view_ratio
like_to_view_ratio = yt_data['likes'].sum() / yt_data['views'].sum()
yt_data['likes'] = yt_data['likes'].fillna(yt_data['views'] * like_to_view_ratio)

#fill missing comments based on comments_to_view_ratio
comment_to_view_ratio = yt_data['comments'].sum() / yt_data['views'].sum()
yt_data['comments'] = yt_data['comments'].fillna(yt_data['views'] * comment_to_view_ratio)

# %%
#Feature engineer a few ratio fields

yt_data['likes_to_views'] = yt_data['likes'] / yt_data['views']
yt_data['comments_to_views'] = yt_data['comments'] / yt_data['views']

# %%
# Filter to show columns with NaN values
na_cols = yt_data.columns[yt_data.isna().any()]
print(yt_data[na_cols].isna().sum())
# Out:
# description             26
# channel_description    121
# dtype: int64

# %%
yt_data.dtypes
# Out:
# video_id                               object
# title                                  object
# description                            object
# video_published_at        datetime64[ns, UTC]
# hours_published_video                 float64
# num_tags                                int64
# channel                                object
# channel_id                             object
# thumbnail_url                          object
# thumbnail_width                         int64
# thumbnail_height                        int64
# duration                                int64
# definition                             object
# caption                                  bool
# views                                   int64
# likes                                 float64
# favorites                               int64
# comments                              float64
# channel_description                    object
# channel_published_at      datetime64[ns, UTC]
# days_published_channel                float64
# channel_views                           int64
# channel_videos                          int64
# channel_subscribers                     int64
# likes_to_views                        float64
# comments_to_views                     float64
# dtype: object

# %%
#one-hot encode object features
yt_data = pd.get_dummies(yt_data, columns=['definition','caption'])

# %%
#log transform variables with a high skewness: 
yt_data['log_views'] = np.log(yt_data['views'])
yt_data['log_hours_published_video'] = np.log(yt_data['hours_published_video'])
yt_data['log_likes'] = np.log(yt_data['likes'])
yt_data['log_comments'] = np.log(yt_data['comments'])
yt_data['log_channel_views'] = np.log(yt_data['channel_views'])
yt_data['log_channel_subscribers'] = np.log(yt_data['channel_subscribers'])
yt_data.drop(columns = ['views','hours_published_video','likes','comments','channel_views','channel_subscribers'], inplace= True)
# Out:
# c:\Users\maxen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\maxen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#need to add some code to turn 'description', 'title', and 'channel_description' into numeric features

# %%
#exclude object types or datetime types. 
yt_data = yt_data.select_dtypes(exclude=["object",'datetime64[ns, UTC]'])
#likes, and comments are all outcome variables rather than predictors. 
#drop these features. Likes / dislikes ratio was discussed but was not included in API data file. 
yt_data.drop(columns= ['log_likes','log_comments'],inplace=True)

# %%
yt_data = yt_data.astype({col: float for col in yt_data.select_dtypes(include='int64').columns})

# %%
yt_data.dtypes
# Out:
# num_tags                     float64
# thumbnail_width              float64
# thumbnail_height             float64
# duration                     float64
# favorites                    float64
# days_published_channel       float64
# channel_videos               float64
# likes_to_views               float64
# comments_to_views            float64
# definition_hd                  uint8
# definition_sd                  uint8
# caption_False                  uint8
# caption_True                   uint8
# log_views                    float64
# log_hours_published_video    float64
# log_channel_views            float64
# log_channel_subscribers      float64
# dtype: object

# %%
yt_data.corr()
# Out:
#                            num_tags  thumbnail_width  thumbnail_height  \
# num_tags                   1.000000              NaN               NaN
# thumbnail_width                 NaN              NaN               NaN
# thumbnail_height                NaN              NaN               NaN
# duration                   0.111038              NaN               NaN
# favorites                       NaN              NaN               NaN
# days_published_channel     0.037335              NaN               NaN
# channel_videos             0.033578              NaN               NaN
# likes_to_views            -0.074046              NaN               NaN
# comments_to_views          0.015394              NaN               NaN
# definition_hd              0.074064              NaN               NaN
# definition_sd             -0.074064              NaN               NaN
# caption_False             -0.031049              NaN               NaN
# caption_True               0.031049              NaN               NaN
# log_views                 -0.005383              NaN               NaN
# log_hours_published_video -0.075736              NaN               NaN
# log_channel_views          0.181021              NaN               NaN
# log_channel_subscribers    0.185995              NaN               NaN
#
#                            duration  favorites  days_published_channel  \
# num_tags                   0.111038        NaN                0.037335
# thumbnail_width                 NaN        NaN                     NaN
# thumbnail_height                NaN        NaN                     NaN
# duration                   1.000000        NaN               -0.099255
# favorites                       NaN        NaN                     NaN
# days_published_channel    -0.099255        NaN                1.000000
# channel_videos            -0.045173        NaN                0.269400
# likes_to_views            -0.040441        NaN               -0.007926
# comments_to_views         -0.034762        NaN               -0.004767
# definition_hd              0.013230        NaN                0.028734
# definition_sd             -0.013230        NaN               -0.028734
# caption_False             -0.011310        NaN               -0.093060
# caption_True               0.011310        NaN                0.093060
# log_views                  0.019200        NaN                0.179115
# log_hours_published_video  0.102673        NaN                0.005878
# log_channel_views         -0.033336        NaN                0.502668
# log_channel_subscribers    0.021161        NaN                0.469206
#
#                            channel_videos  likes_to_views  comments_to_views  \
# num_tags                         0.033578       -0.074046           0.015394
# thumbnail_width                       NaN             NaN                NaN
# thumbnail_height                      NaN             NaN                NaN
# duration                        -0.045173       -0.040441          -0.034762
# favorites                             NaN             NaN                NaN
# days_published_channel           0.269400       -0.007926          -0.004767
# channel_videos                   1.000000       -0.130114           0.050642
# likes_to_views                  -0.130114        1.000000           0.462801
# comments_to_views                0.050642        0.462801           1.000000
# definition_hd                   -0.075177       -0.005911           0.046681
# definition_sd                    0.075177        0.005911          -0.046681
# caption_False                   -0.071079        0.071551           0.048387
# caption_True                     0.071079       -0.071551          -0.048387
# log_views                       -0.050975       -0.369959          -0.337068
# log_hours_published_video       -0.164146       -0.419550          -0.395099
# log_channel_views                0.244927       -0.055616          -0.114358
# log_channel_subscribers          0.175114        0.016347          -0.064208
#
#                            definition_hd  definition_sd  caption_False  \
# num_tags                        0.074064      -0.074064      -0.031049
# thumbnail_width                      NaN            NaN            NaN
# thumbnail_height                     NaN            NaN            NaN
# duration                        0.013230      -0.013230      -0.011310
# favorites                            NaN            NaN            NaN
# days_published_channel          0.028734      -0.028734      -0.093060
# channel_videos                 -0.075177       0.075177      -0.071079
# likes_to_views                 -0.005911       0.005911       0.071551
# comments_to_views               0.046681      -0.046681       0.048387
# definition_hd                   1.000000      -1.000000      -0.050119
# definition_sd                  -1.000000       1.000000       0.050119
# caption_False                  -0.050119       0.050119       1.000000
# caption_True                    0.050119      -0.050119      -1.000000
# log_views                       0.038689      -0.038689      -0.149915
# log_hours_published_video      -0.062163       0.062163      -0.083925
# log_channel_views               0.107992      -0.107992      -0.126147
# log_channel_subscribers         0.135192      -0.135192      -0.140297
#
#                            caption_True  log_views  log_hours_published_video  \
# num_tags                       0.031049  -0.005383                  -0.075736
# thumbnail_width                     NaN        NaN                        NaN
# thumbnail_height                    NaN        NaN                        NaN
# duration                       0.011310   0.019200                   0.102673
# favorites                           NaN        NaN                        NaN
# days_published_channel         0.093060   0.179115                   0.005878
# channel_videos                 0.071079  -0.050975                  -0.164146
# likes_to_views                -0.071551  -0.369959                  -0.419550
# comments_to_views             -0.048387  -0.337068                  -0.395099
# definition_hd                  0.050119   0.038689                  -0.062163
# definition_sd                 -0.050119  -0.038689                   0.062163
# caption_False                 -1.000000  -0.149915                  -0.083925
# caption_True                   1.000000   0.149915                   0.083925
# log_views                      0.149915   1.000000                   0.582111
# log_hours_published_video      0.083925   0.582111                   1.000000
# log_channel_views              0.126147   0.573364                   0.037126
# log_channel_subscribers        0.140297   0.568375                   0.044980
#
#                            log_channel_views  log_channel_subscribers
# num_tags                            0.181021                 0.185995
# thumbnail_width                          NaN                      NaN
# thumbnail_height                         NaN                      NaN
# duration                           -0.033336                 0.021161
# favorites                                NaN                      NaN
# days_published_channel              0.502668                 0.469206
# channel_videos                      0.244927                 0.175114
# likes_to_views                     -0.055616                 0.016347
# comments_to_views                  -0.114358                -0.064208
# definition_hd                       0.107992                 0.135192
# definition_sd                      -0.107992                -0.135192
# caption_False                      -0.126147                -0.140297
# caption_True                        0.126147                 0.140297
# log_views                           0.573364                 0.568375
# log_hours_published_video           0.037126                 0.044980
# log_channel_views                   1.000000                 0.955355
# log_channel_subscribers             0.955355                 1.000000

# %%
#thumbnail width, thumbnail height, and favorites only contain a single value each 
#with no variability. Drop these features. 
yt_data.drop(columns= ['thumbnail_height','thumbnail_width','favorites'], inplace= True)

# %%
#drop channel_views since highly correlated with channel_subscribers
yt_data.drop(columns=['log_channel_views'], inplace = True)

# %% [markdown]
# ### Split into training & test sets

# %%
# 1,274 rows total -- approx 80/20 split
yt_train = yt_data[:1000]
yt_test = yt_data[1000:]

X_yt_train = yt_train.drop(['log_views'], axis=1)
y_yt_train = yt_train['log_views']
X_yt_test = yt_test.drop(['log_views'], axis=1)
y_yt_test = yt_test['log_views']

print("Train Shape:", yt_train.shape)
print("Test Shape:", yt_test.shape)
# Out:
# Train Shape: (1000, 13)
# Test Shape: (274, 13)

# %% [markdown]
# ### Baseline Model
#
# Find the average/mean number of views from the training set and make that
# the (constant) prediction.
#
# $Y$ = $W_0$ + $W_1x_1$ + $W_2x_2$ + ... + $W_ix_i$
#
# where $W_0$ (intercept) is the mean number of views

# %%
from sklearn.metrics import r2_score

# %%
# set up arrays of 1s as the "feature" for the baseline model's intercept/bias
base_train_1s = np.ones(shape=(yt_train.shape[0], 1))
base_test_1s = np.ones(shape=(yt_test.shape[0], 1))

# baseline model's bias/intercept is the average # of views in the training set
print(f"Average Log Views (Train): {np.mean(yt_train['log_views']):0.2f}\n")
base_weights = np.array([np.mean(yt_train['log_views'])])

# calculate predictions, errors, and rmse for training set
base_train_predictions = np.dot(base_train_1s, base_weights.transpose())
base_train_errors = base_train_predictions - yt_train['log_views']
base_train_rmse = np.mean(base_train_errors ** 2) ** 0.5
print(f"Baseline RMSE (Train): {base_train_rmse:0.2f}")

# calculate predictions, errors, and rmse for test set
base_test_predictions = np.dot(base_test_1s, base_weights.transpose())
base_test_errors = base_test_predictions - yt_test['log_views']
base_test_rmse = np.mean(base_test_errors ** 2) ** 0.5
print(f"Baseline RMSE (Test): {base_test_rmse:0.2f}")
coefficient_of_dermination = r2_score(yt_test['log_views'], base_test_predictions)
print("Model accuracy on test set: {:.2f}".format(coefficient_of_dermination))
# Out:
# Average Log Views (Train): 13.31
#
# Baseline RMSE (Train): 2.27
# Baseline RMSE (Test): 2.14
# Model accuracy on test set: -0.00

# %% [markdown]
# ### Model: Linear Regression with gradient descent

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_yt_train_std = sc.fit_transform(X_yt_train)
X_yt_test_std = sc.transform(X_yt_test)

# %%
import tensorflow as tf

# %%
from keras import backend as K

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))
    
def det_coeff(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
def build_model(num_features, learning_rate):
  """Build a TF linear regression model using Keras.

  Args:
    num_features: The number of input features.
    learning_rate: The desired learning rate for SGD.

  Returns:
    model: A tf.keras model (graph).
  """
  tf.keras.backend.clear_session()
  tf.random.set_seed(0)

  # Build a model using keras.Sequential. While this is intended for neural
  # networks (which may have multiple layers), we want just a single layer for
  # linear regression.
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Dense(
      units=1,                     # output dim
      input_shape=[num_features],  # input dim
      use_bias=True,               # use a bias (intercept) param
      kernel_initializer=tf.keras.initializers.Constant(value = np.log(1)),  # initialize params to 1
      bias_initializer=tf.keras.initializers.Constant(value= np.log(1))    # initialize bias to 1
  ))

  # We need to choose an optimizer. We'll use SGD, which is actually mini-batch
  # SGD. We can specify the batch size to use for training later.
  optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)

  # Finally, we compile the model. This finalizes the graph for training.
  # We specify the MSE loss.
  model.compile(loss=root_mean_squared_error, optimizer=optimizer, metrics=[det_coeff])
  return model

# %%
def plot_loss(model, history):
  """Plot the loss after each training epoch."""
  # Convert the history object into a DataFrame.
  history = pd.DataFrame(history.history)

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.plot(range(len(history)), history['loss'], marker='.', color='black')
  plt.plot(range(len(history)), history['val_loss'], marker='.', color='red')
  plt.legend(['train loss', 'validation loss'])
  plt.show()

  # Show the final train loss value and the learned model weights.
  print('Final train loss:', list(history['loss'])[-1])
  print('Final score: ', list(history['det_coeff'])[-1])
  print('Final weights:', model.layers[0].get_weights())
  print('Final validation loss:', list(history['val_loss'])[-1])

# %%
#linear regression with gradient descent with learning rate = 0.1
model = build_model(num_features=len(X_yt_train.columns), learning_rate=.1)

history = model.fit(
  x = X_yt_train_std,
  y = y_yt_train,
  validation_split=0.1,  # use 10% of the examples as a validation set
  epochs=150,
  batch_size=200,
  verbose=0)

plot_loss(model, history)

# calculate model prediction rmse for test data 
test_rmse = model.evaluate(X_yt_test_std,
                             y_yt_test,
                             verbose=0)
print('----------Test set performance ---------')
print("Model accuracy on test set: {:.2f}".format(test_rmse[1]))
print("The root mean squared error (RMSE) on test set: {:.2f}".format(test_rmse[0]))
# Out:
# Final train loss: 1.2516478300094604
# Final score:  0.668681263923645
# Final weights: [array([[-0.22153488],
#        [-0.08609357],
#        [-0.19089195],
#        [-0.23451258],
#        [-0.5317805 ],
#        [-0.02009164],
#        [-0.02852012],
#        [ 0.02852012],
#        [-0.0268561 ],
#        [ 0.0268561 ],
#        [ 0.9256752 ],
#        [ 1.3736837 ]], dtype=float32), array([13.304162], dtype=float32)]
# Final validation loss: 1.3193919658660889
# ----------Test set performance ---------
# Model accuracy on test set: 0.64
# The root mean squared error (RMSE) on test set: 1.25

# %% [markdown]
# ### Model: Gradient Boosted Decision Trees

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

boosted_model = GradientBoostingRegressor(n_estimators=1000, learning_rate=0.1, max_depth=5, random_state=42)
boosted_model.fit(X_yt_train_std, y_yt_train)

# Print Coefficient of determination R^2
print("Model Accuracy: %.2f" % boosted_model.score(X_yt_test_std, y_yt_test))

# Create the mean squared error
rmse = np.sqrt(mean_squared_error(y_yt_test, boosted_model.predict(X_yt_test_std)))
print("The root mean squared error (RMSE) on test set: {:.2f}".format(rmse))
# Out:
# Model Accuracy: 0.77
# The root mean squared error (RMSE) on test set: 1.03

# %%
from sklearn.inspection import permutation_importance
#
# Get Feature importance data using feature_importances_ attribute
#
feature_importance = boosted_model.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(list(X_yt_train.columns))[sorted_idx])
plt.title('Feature Importance ')
result = permutation_importance(boosted_model, X_yt_test_std, y_yt_test, n_repeats=10,
                                random_state=42, n_jobs=2)
sorted_idx = result.importances_mean.argsort()
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Model: Random Forest
# This model was optimized using TPOT, an AutoML library.

# %%
from sklearn.ensemble import RandomForestRegressor

# Average CV score on the training set was: -1.3537844790161722
tpot_model_1 = RandomForestRegressor(
    bootstrap=False,
    max_features=0.65,
    min_samples_leaf=1,
    min_samples_split=15,
    n_estimators=100
)

tpot_model_1.fit(X_yt_train, y_yt_train)

# Print Coefficient of determination R^2
print(f"Model Accuracy: {tpot_model_1.score(X_yt_test, y_yt_test):.2f}")

# Create the mean squared error
rmse_tpot_model_1 = np.sqrt(mean_squared_error(y_yt_test, tpot_model_1.predict(X_yt_test)))
print(f"The root mean squared error (RMSE) on test set: {rmse_tpot_model_1:.2f}")
# Out:
# Model Accuracy: 0.80
# The root mean squared error (RMSE) on test set: 0.96

# %%
# Get Feature importance data using feature_importances_ attribute
feature_importance = tpot_model_1.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig = plt.figure(figsize=(8, 8))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(list(X_yt_train.columns))[sorted_idx])
plt.title('Feature Importance')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Model: Neural Net
